# %% [markdown]
# # Условия и уравнения
#
# Вариант 15

# %% [markdown]
# ## Условия

# %% [markdown]
# $u'' - u' - u = 3\sin(x) - \cos(x)$
#
# $u'(0) = -1$
#
# $u(1) + 2u'(1) = -(\cos(1) + 3\sin(1))$
#
# $u(x) = \cos(x) - \sin(x)$

# %% [markdown]
# # Решение

# %% [markdown]
# $u(x) \approx 0.12 x^3 - 0.43296 x^2 - x + 1.26$

# %%
import numpy as np
from numpy import cos, sin

# %%
import matplotlib.pyplot as plt

# %%
def u(x):
    return 0.12 * pow(x, 3) - 0.43296 * pow(x, 2) - x + 1.26

# %%
def du(x):
    return (9 / 25) * pow(x, 2) - (2706 / 3125) * x - 1

# %%
def u_t(x):
    return cos(x) - sin(x)

# %%
x_r = np.linspace(0, 1, 100)

y_p = u(x_r)
y_t = u_t(x_r)

# %%
u(0), du(0)
# Out:
# (1.26, -1.0)

# %%
plt.plot(x_r, y_p, label="predict")
plt.plot(x_r, y_t, label="true")

plt.legend()
